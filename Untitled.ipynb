# %%
# %pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# type: ignore
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
# Creating a sample dataset
data = {
    'Age': [23, 25, 22, 30, 28, 35, 40, 23, 24, 22],
    'Height': [165, 170, 160, 175, 180, 172, 168, 158, 165, 170],
    'Weight': [65, 70, 60, 75, 80, 72, 68, 58, 65, 70],
    'Gender': ['Male', 'Female', 'Female', 'Male', 'Male', 'Female', 'Male', 'Female', 'Female', 'Male'],
    'Smoker': ['No', 'Yes', 'No', 'No', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
}
df = pd.DataFrame(data)

# %%
# Step 1: Understand the Data
print("Data Types:\n", df.dtypes)
print("\nSummary Statistics:\n", df.describe())
# Out:
# Data Types:
#  Age        int64
# Height     int64
# Weight     int64
# Gender    object
# Smoker    object
# dtype: object
#
# Summary Statistics:
#               Age      Height     Weight
# count  10.000000   10.000000  10.000000
# mean   27.200000  168.300000  68.300000
# std     6.124632    6.650814   6.650814
# min    22.000000  158.000000  58.000000
# 25%    23.000000  165.000000  65.000000
# 50%    24.500000  169.000000  69.000000
# 75%    29.500000  171.500000  71.500000
# max    40.000000  180.000000  80.000000

# %%
# Step 2: Univariate Analysis - Numerical Data
plt.figure(figsize=(10, 4))

plt.subplot(1, 3, 1)
sns.histplot(df['Age'], kde=True, color='blue')
plt.title('Age Distribution (Discrete Data)')
     
plt.subplot(1, 3, 2)
sns.histplot(df['Height'], kde=True, color='green')
plt.title('Height Distribution (Continuous Data)')

plt.subplot(1, 3, 3)
sns.histplot(df['Weight'], kde=True, color='red')
plt.title('Weight Distribution (Continuous Data)')

plt.tight_layout()
plt.show()

# %%
# Step 4: Bivariate Analysis - Numerical Data
sns.scatterplot(x='Age', y='Weight', hue='Gender', data=df)
plt.title('Scatter Plot of Age vs Weight')
plt.show()

# %%
# Step 5: Outlier Detection - Boxplot
plt.figure(figsize=(8, 6))
sns.boxplot(x='Gender', y='Height', data=df)
plt.title('Boxplot of Height by Gender')
plt.show()

# %%
# Step 6: Feature Engineering
# Let's create a new feature: BMI (Body Mass Index)
df['BMI'] = df['Weight'] / (df['Height'] / 100) ** 2
print("\nData with new BMI feature:\n", df)
# Out:
# Data with new BMI feature:
#     Age  Height  Weight  Gender Smoker        BMI
# 0   23     165      65    Male     No  23.875115
# 1   25     170      70  Female    Yes  24.221453
# 2   22     160      60  Female     No  23.437500
# 3   30     175      75    Male     No  24.489796
# 4   28     180      80    Male    Yes  24.691358
# 5   35     172      72  Female     No  24.337480
# 6   40     168      68    Male    Yes  24.092971
# 7   23     158      58  Female     No  23.233456
# 8   24     165      65  Female    Yes  23.875115
# 9   22     170      70    Male     No  24.221453

# %%
# Step 7: Visualization of the new feature
sns.histplot(df['BMI'], kde=True, color='purple')
plt.title('BMI Distribution')
plt.show()

# %% [markdown]
# #
